# %%
###Module 5: Unit testing

# %%
import unittest


class TestSum(unittest.TestCase):

    def test_sum(self):
        self.assertEqual(sum([1, 2, 3]), 6, "Should be 6")

    def test_sum_tuple(self):
        self.assertEqual(sum((1, 2, 2)), 6, "Should be 6")

if __name__ == '__main__':
    unittest.main()


"""

 python -u "/Users/maiwasetembo/Desktop/Ivy Tech/Software Dev using Python/Module05/module05python/practice_unittest.py"
.F
======================================================================
FAIL: test_sum_tuple (__main__.TestSum.test_sum_tuple)
----------------------------------------------------------------------
Traceback (most recent call last):
  File "/Users/maiwasetembo/Desktop/Ivy Tech/Software Dev using Python/Module05/module05python/practice_unittest.py", line 10, in test_sum_tuple
    self.assertEqual(sum((1, 2, 2)), 6, "Should be 6")
AssertionError: 5 != 6 : Should be 6

----------------------------------------------------------------------
Ran 2 tests in 0.000s

FAILED (failures=1)

[Done] exited with code=1 in 0.052 seconds

"""

###Explanation:
# When an assertion fails in Python's unittest framework, it raises an AssertionError and provides details about the mismatch, helping to identify the issue. Debugging involves using the traceback and analyzing the test logic to pinpoint why the test failed and making necessary corrections. Test result symbols include a dot (.) for a successfully passed test and an F for a failed test, with a summary at the end indicating the total number of tests run and the number of failures.

# %%
import unittest

from my_sum import sum
from fractions import Fraction

class TestSum(unittest.TestCase):
    def test_list_int(self):
        """
        Test that it can sum a list of integers
        """
        data = [1, 2, 3]
        result = sum(data)
        self.assertEqual(result, 6)

    def test_list_fraction(self):
        """
        Test that it can sum a list of fractions
        """
        data = [Fraction(1, 4), Fraction(1, 4), Fraction(2, 5)]
        result = sum(data)
        self.assertEqual(result, 1)
if __name__ == '__main__':
    unittest.main()


"""
[Running] python -u "/Users/maiwasetembo/Desktop/Ivy Tech/Software Dev using Python/Module05/module05python/test.py"
F.
======================================================================
FAIL: test_list_fraction (__main__.TestSum.test_list_fraction)
Test that it can sum a list of fractions
----------------------------------------------------------------------
Traceback (most recent call last):
  File "/Users/maiwasetembo/Desktop/Ivy Tech/Software Dev using Python/Module05/module05python/test.py", line 21, in test_list_fraction
    self.assertEqual(result, 1)
AssertionError: Fraction(9, 10) != 1

----------------------------------------------------------------------
Ran 2 tests in 0.000s

FAILED (failures=1)

[Done] exited with code=1 in 0.087 seconds


"""

###Explanation

#The output shows that two tests were executed, one of which failed, as indicated by the F. in the results. The failure occurred in the test_list_fraction function, part of the TestSum test case. This test checks if the function can correctly sum a list of fractions and asserts that the result should equal 1. However, the test failed because the actual result was Fraction(9, 10), which does not match the expected value of 1. The AssertionError provides a clear comparison of the expected and actual results, helping to identify the issue. The traceback points to line 21 in the test.py file, where the failing assertion was made, aiding in debugging. The summary indicates that two tests were run in a very short time (0.000s), and one test failed. The developer can use this information to analyze why the summing function did not return the expected result and adjust the code or test as necessary.
